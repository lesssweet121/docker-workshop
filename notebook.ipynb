# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine(
    "postgresql+psycopg://root:root@localhost:5432/ny_taxi"
)

pd.read_sql("SELECT 1 AS ok;", engine)
# Out:
#    ok
# 0   1

# %%
engine = create_engine(
    "postgresql+psycopg://root:root@ny_taxi_pg:5432/ny_taxi"
)

# %%
import pandas as pd

# %%
# Read a sample of the data
prefix = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/'
df = pd.read_csv(prefix + 'yellow_tripdata_2021-01.csv.gz', nrows=100)

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# 1           0.20           1                  N           238           151
# 2          14.70           1                  N           132           165
# 3          10.60           1                  N           138           132
# 4           4.94           1                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          8.0    3.0      0.5        0.00           0.0
# 1             2          3.0    0.5      0.5        0.00           0.0
# 2             1         42.0    0.5      0.5        8.65           0.0
# 3             1         29.0    0.5      0.5        6.05           0.0
# 4             1         16.5    0.5      0.5        4.06           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                    0.3         11.80                   2.5
# 1                    0.3          4.30                   0.0
# 2                    0.3         51.95                   0.0
# 3                    0.3         36.35                   0.0
# 4                    0.3         24.36                   2.5

# %%
len(df)
# Out:
# 100

# %%
df

# %%
df['tpep_pickup_datetime']

# %%
dtype = {
    "VendorID": "Int64",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "congestion_surcharge": "float64"
}

parse_dates = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]

df = pd.read_csv(
    prefix + 'yellow_tripdata_2021-01.csv.gz',
    nrows=100,
    dtype=dtype,
    parse_dates=parse_dates
)

# %%
df.head()

# %%
df['tpep_pickup_datetime']
# Out:
# 0    2021-01-01 00:30:10
# 1    2021-01-01 00:51:20
# 2    2021-01-01 00:43:30
# 3    2021-01-01 00:15:48
# 4    2021-01-01 00:31:49
#              ...
# 95   2021-01-01 00:12:41
# 96   2021-01-01 00:23:29
# 97   2021-01-01 00:46:17
# 98   2021-01-01 00:28:16
# 99   2021-01-01 00:42:35
# Name: tpep_pickup_datetime, Length: 100, dtype: datetime64[ns]

# %%
# !uv add sqlalchemy
# Out:
# Resolved 121 packages in 1ms
# Audited 12 packages in 0.20ms

# %%
# !uv add psycopg2-binary
# Out:
# Resolved 121 packages in 1ms
# Audited 12 packages in 0.19ms

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge]
# Index: []

# %%
df.head(0).to_sql(
    name="yellow_taxi_data",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 0

# %%
# !nc -vz localhost 5432
# Out:
# /bin/bash: line 1: nc: command not found

# %%
# !nc -vz localhost 5432
# Out:
# /bin/bash: line 1: nc: command not found

# %%
len(df)
# Out:
# 100

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# !uv add tqdm
# Out:
# Resolved 121 packages in 1ms
# Audited 12 packages in 0.20ms

# %%
df_iter = pd.read_csv(
    prefix + 'yellow_tripdata_2021-01.csv.gz',
    dtype=dtype,
    parse_dates=parse_dates,
    iterator=True,
    chunksize=100000
)

# %%
from tqdm.auto import tqdm

# %%
for df_chunk in tqdm(df_iter):
    df_chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[26], line 2
#       1 for df_chunk in tqdm(df_iter):
# ----> 2     df_chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/pandas/core/generic.py:3109, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2911 """
#    2912 Write records stored in a DataFrame to a SQL database.
#    2913
#    (...)   3105 [(1,), (None,), (2,)]
#    3106 """  # noqa: E501
#    3107 from pandas.io import sql
# -> 3109 return sql.to_sql(
#    3110     self,
#    3111     name,
#    3112     con,
#    3113     schema=schema,
#    3114     if_exists=if_exists,
#    3115     index=index,
#    3116     index_label=index_label,
#    3117     chunksize=chunksize,
#    3118     dtype=dtype,
#    3119     method=method,
#    3120 )
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/pandas/io/sql.py:843, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     838 elif not isinstance(frame, DataFrame):
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
# --> 843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#    (...)    855         **engine_kwargs,
#     856     )
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/pandas/io/sql.py:1657, in SQLDatabase.__exit__(self, *args)
#    1655 def __exit__(self, *args) -> None:
#    1656     if not self.returns_generator:
# -> 1657         self.exit_stack.close()
#
# File ~/.local/share/uv/python/cpython-3.13.11-linux-x86_64-gnu/lib/python3.13/contextlib.py:627, in ExitStack.close(self)
#     625 def close(self):
#     626     """Immediately unwind the context stack."""
# --> 627     self.__exit__(None, None, None)
#
# File ~/.local/share/uv/python/cpython-3.13.11-linux-x86_64-gnu/lib/python3.13/contextlib.py:619, in ExitStack.__exit__(self, *exc_details)
#     615 try:
#     616     # bare "raise exc" replaces our carefully
#     617     # set-up context
#     618     fixed_ctx = exc.__context__
# --> 619     raise exc
#     620 except BaseException:
#     621     exc.__context__ = fixed_ctx
#
# File ~/.local/share/uv/python/cpython-3.13.11-linux-x86_64-gnu/lib/python3.13/contextlib.py:604, in ExitStack.__exit__(self, *exc_details)
#     602 else:
#     603     exc_details = type(exc), exc, exc.__traceback__
# --> 604 if cb(*exc_details):
#     605     suppressed_exc = True
#     606     pending_raise = False
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/sqlalchemy/engine/util.py:147, in TransactionalContext.__exit__(self, type_, value, traceback)
#     145     self.commit()
#     146 except:
# --> 147     with util.safe_reraise():
#     148         if self._rollback_can_be_called():
#     149             self.rollback()
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/sqlalchemy/engine/util.py:145, in TransactionalContext.__exit__(self, type_, value, traceback)
#     143 if type_ is None and self._transaction_is_active():
#     144     try:
# --> 145         self.commit()
#     146     except:
#     147         with util.safe_reraise():
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2640, in Transaction.commit(self)
#    2624 """Commit this :class:`.Transaction`.
#    2625
#    2626 The implementation of this may vary based on the type of transaction in
#    (...)   2637
#    2638 """
#    2639 try:
# -> 2640     self._do_commit()
#    2641 finally:
#    2642     assert not self.is_active
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2745, in RootTransaction._do_commit(self)
#    2742 assert self.connection._transaction is self
#    2744 try:
# -> 2745     self._connection_commit_impl()
#    2746 finally:
#    2747     # whether or not commit succeeds, cancel any
#    2748     # nested transactions, make this transaction "inactive"
#    2749     # and remove it as a reset agent
#    2750     if self.connection._nested_transaction:
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2716, in RootTransaction._connection_commit_impl(self)
#    2715 def _connection_commit_impl(self) -> None:
# -> 2716     self.connection._commit_impl()
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1147, in Connection._commit_impl(self)
#    1145     self.engine.dialect.do_commit(self.connection)
#    1146 except BaseException as e:
# -> 1147     self._handle_dbapi_exception(e, None, None, None, None)
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2366, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2364     else:
#    2365         assert exc_info[1] is not None
# -> 2366         raise exc_info[1].with_traceback(exc_info[2])
#    2367 finally:
#    2368     del self._reentrant_error
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1145, in Connection._commit_impl(self)
#    1143         self._log_info("COMMIT")
#    1144 try:
# -> 1145     self.engine.dialect.do_commit(self.connection)
#    1146 except BaseException as e:
#    1147     self._handle_dbapi_exception(e, None, None, None, None)
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:581, in Connection.connection(self)
#     579 if self._dbapi_connection is None:
#     580     try:
# --> 581         return self._revalidate_connection()
#     582     except (exc.PendingRollbackError, exc.ResourceClosedError):
#     583         raise
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:673, in Connection._revalidate_connection(self)
#     671 if self.__can_reconnect and self.invalidated:
#     672     if self._transaction is not None:
# --> 673         self._invalid_transaction()
#     674     self._dbapi_connection = self.engine.raw_connection()
#     675     return self._dbapi_connection
#
# File /workspaces/docker-workshop/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:663, in Connection._invalid_transaction(self)
#     662 def _invalid_transaction(self) -> NoReturn:
# --> 663     raise exc.PendingRollbackError(
#     664         "Can't reconnect until invalid %stransaction is rolled "
#     665         "back.  Please rollback() fully before proceeding"
#     666         % ("savepoint " if self._nested_transaction is not None else ""),
#     667         code="8s2b",
#     668     )
#
# PendingRollbackError: Can't reconnect until invalid transaction is rolled back.  Please rollback() fully before proceeding (Background on this error at: https://sqlalche.me/e/20/8s2b)

# %%
import pandas as pd
from sqlalchemy import create_engine



df_zones = pd.read_csv(
    "https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv"
)

df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df_zones.to_sql(
    name="zones",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 265

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine(
    "postgresql+psycopg://root:root@localhost:5432/ny_taxi"
)

pd.read_sql("SELECT 1 AS ok;", engine)
# Out:
#    ok
# 0   1

# %%
df_Nov2025 = pd.read_parquet(
    "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-11.parquet"
)

df_Nov2025.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         7  2025-11-01 00:13:25   2025-11-01 00:13:25              1.0
# 1         2  2025-11-01 00:49:07   2025-11-01 01:01:22              1.0
# 2         1  2025-11-01 00:07:19   2025-11-01 00:20:41              0.0
# 3         2  2025-11-01 00:00:00   2025-11-01 01:01:03              3.0
# 4         1  2025-11-01 00:18:50   2025-11-01 00:49:32              0.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.68         1.0                  N            43           186
# 1           2.28         1.0                  N           142           237
# 2           2.70         1.0                  N           163           238
# 3          12.87         1.0                  N           138           261
# 4           8.40         1.0                  N           138            37
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         14.9   0.00      0.5        1.50          0.00
# 1             1         14.2   1.00      0.5        4.99          0.00
# 2             1         15.6   4.25      0.5        4.27          0.00
# 3             1         66.7   6.00      0.5        0.00          6.94
# 4             2         39.4   7.75      0.5        0.00          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                    1.0         22.15                   2.5         0.00
# 1                    1.0         24.94                   2.5         0.00
# 2                    1.0         25.62                   2.5         0.00
# 3                    1.0         86.14                   2.5         1.75
# 4                    1.0         48.65                   0.0         1.75
#
#    cbd_congestion_fee
# 0                0.75
# 1                0.75
# 2                0.75
# 3                0.75
# 4                0.00

# %%
df_Nov2025.shape
# Out:
# (4181444, 20)

# %%
df_Nov2025.to_sql(
    name="Nov2025",
    con=engine,
    if_exists="replace",
    index=False
)
